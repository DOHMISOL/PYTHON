# %% [markdown]
# ##공공데이터 수집

# %%
targetUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002633405&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B4%80%EB%A0%A8%20%EC%A7%80%EC%88%98_20160101"

# %%
import pandas as pd

# %%
indata = pd.read_csv(targetUrl, encoding = "ms949")

# %%
indata
# Out:
#      지역  2020-07  2020-08  2020-09  2020-10  2020-11  2020-12  2021-01  \
# 0    전국   99.958   99.977   99.942   99.986   99.956   99.992  100.050
# 1   수도권   99.973  100.025  100.018  100.073  100.061  100.116  100.202
# 2    지방   99.898   99.779   99.624   99.625   99.524   99.482   99.424
# 3    서울  100.032  100.105  100.122  100.166  100.117  100.135  100.207
# 4   도심권  100.051  100.121  100.135  100.170  100.181  100.184  100.291
# 5   동북권  100.059  100.060  100.172  100.233  100.320  100.384  100.542
# 6   서북권  100.030  100.018   99.979   99.985   99.819   99.802   99.769
# 7   서남권  100.016  100.109  100.142  100.179  100.155  100.203  100.281
# 8   동남권  100.035  100.160  100.133  100.199  100.079  100.056  100.115
# 9    부산   99.910   99.780   99.579   99.579   99.489   99.454   99.378
# 10   대구   99.979   99.893   99.822   99.896   99.637   99.787   99.670
# 11   인천   99.826   99.761   99.632   99.620   99.540   99.480   99.465
# ...

# %%
indata.tail(2)
# Out:
#              연도  전국소득대비 주택가격 비율  서울소득대비 주택가격 비율  부산소득대비 주택가격 비율  \
# 141  2015-01-01            5.68            7.18            5.78
# 142  2016-01-01            4.31            7.30            5.73
#
#      대구소득대비 주택가격 비율  인천소득대비 주택가격 비율  광주소득대비 주택가격 비율  대전소득대비 주택가격 비율  \
# 141            6.48            5.76            5.46            5.17
# 142            6.88            5.74            4.92            4.79
#
#      울산소득대비 주택가격 비율  세종소득대비 주택가격 비율  ...  세종평균 대출금액  평균 연소득  \
# 141            5.11            5.22  ...               2.17
# 142            5.38            5.76  ...               2.39
#
#      경기평균 대출금액  평균 연소득  강원평균 대출금액  평균 연소득  충북평균 대출금액  평균 연소득  \
# 141               2.56               1.95               2.11
# 142               2.38               1.74               1.83
#
#      충남평균 대출금액  평균 연소득  전북평균 대출금액  평균 연소득  전남평균 대출금액  평균 연소득  \
# 141               2.02               1.88               1.67
# 142               1.81               1.63               1.75
#
# ...

# %%
targetUrl1 = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002579925&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EB%B6%80%EB%8F%99%EC%82%B0%EC%9B%90_%EC%98%A4%ED%94%BC%EC%8A%A4%ED%85%94%20%EA%B0%80%EA%B2%A9%EB%8F%99%ED%96%A5%EC%A1%B0%EC%82%AC_%EB%A7%A4%EB%A7%A4%EA%B0%80%EA%B2%A9%EC%A7%80%EC%88%98(%EC%A7%80%EC%97%AD%EB%B3%84)_20220630"

# %%
import pandas as pd

# %%
indata1 = pd.read_csv(targetUrl1,encoding = "ms949")

# %%
indata
# Out:
#      지역  2020-07  2020-08  2020-09  2020-10  2020-11  2020-12  2021-01  \
# 0    전국   99.958   99.977   99.942   99.986   99.956   99.992  100.050
# 1   수도권   99.973  100.025  100.018  100.073  100.061  100.116  100.202
# 2    지방   99.898   99.779   99.624   99.625   99.524   99.482   99.424
# 3    서울  100.032  100.105  100.122  100.166  100.117  100.135  100.207
# 4   도심권  100.051  100.121  100.135  100.170  100.181  100.184  100.291
# 5   동북권  100.059  100.060  100.172  100.233  100.320  100.384  100.542
# 6   서북권  100.030  100.018   99.979   99.985   99.819   99.802   99.769
# 7   서남권  100.016  100.109  100.142  100.179  100.155  100.203  100.281
# 8   동남권  100.035  100.160  100.133  100.199  100.079  100.056  100.115
# 9    부산   99.910   99.780   99.579   99.579   99.489   99.454   99.378
# 10   대구   99.979   99.893   99.822   99.896   99.637   99.787   99.670
# 11   인천   99.826   99.761   99.632   99.620   99.540   99.480   99.465
# ...

# %%
jsonUrl ="https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=NWRlMjczODBmMDQ3NTM4NjUwNTg3ZGI0ZTM2MjA0NWE=&itmId=T20+T21+T22+&objL1=ALL&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&newEstPrdCnt=3&orgId=101&tblId=DT_1B040A3"

# %%
manData = pd.read_json(jsonUrl)
manData.head(10)
# Out:
#               TBL_NM  PRD_DE      TBL_ID ITM_NM        ITM_NM_ENG ITM_ID  \
# 0  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3   총인구수   Koreans (Total)    T20
# 1  행정구역(시군구)별 성별 인구수  202301  DT_1B040A3   총인구수   Koreans (Total)    T20
# 2  행정구역(시군구)별 성별 인구수  202302  DT_1B040A3   총인구수   Koreans (Total)    T20
# 3  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 4  행정구역(시군구)별 성별 인구수  202301  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 5  행정구역(시군구)별 성별 인구수  202302  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 6  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 7  행정구역(시군구)별 성별 인구수  202301  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 8  행정구역(시군구)별 성별 인구수  202302  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 9  행정구역(시군구)별 성별 인구수  202212  DT_1B040A3   총인구수   Koreans (Total)    T20
#
#   UNIT_NM  ORG_ID UNIT_NM_ENG   C1_OBJ_NM               C1_OBJ_NM_ENG  \
# 0       명     101      Person  행정구역(시군구)별  By Administrative District
# ...

# %%
LoanUrl = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=NWRlMjczODBmMDQ3NTM4NjUwNTg3ZGI0ZTM2MjA0NWE=&itmId=T001+&objL1=ALL&objL2=ALL&objL3=ALL&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Y&newEstPrdCnt=3&orgId=101&tblId=DT_1MA0028"

# %%
LoanData = pd.read_Loan(LoanUrl)
LoanData.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9712\3890298915.py in <module>
# ----> 1 LoanData = pd.read_Loan(LoanUrl)
#       2 LoanData.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'read_Loan'

# %%
import requests
import bs4

# %%
urlInfo = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002579925&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EB%B6%80%EB%8F%99%EC%82%B0%EC%9B%90_%EC%98%A4%ED%94%BC%EC%8A%A4%ED%85%94%20%EA%B0%80%EA%B2%A9%EB%8F%99%ED%96%A5%EC%A1%B0%EC%82%AC_%EB%A7%A4%EB%A7%A4%EA%B0%80%EA%B2%A9%EC%A7%80%EC%88%98(%EC%A7%80%EC%97%AD%EB%B3%84)_20220630"

# %%
resq= requests.get(urlInfo)

# %%
xmlObj = resq.text

# %%
bsObj = bs4.BeautifulSoup(xmlObj,"lxml-xml")

# %%
rows = bsObj.findAll("item")

# %%
totalCoumnLen = 28

# %%
rowList = []

# %%
columnList = []

# %%
LAWCODE = ["11111","22222","3333"]

# %%
for lwad(0,200000)
# Out:
#   File "C:\Users\SMART27\AppData\Local\Temp\ipykernel_5748\4268247219.py", line 1
#     for lwad(0,200000)
#         ^
# SyntaxError: cannot assign to function call

# %%
#페이지 수집하는 FOR문이다.
for k in range(0,10)
# Out:
#   File "C:\Users\SMART27\AppData\Local\Temp\ipykernel_5748\2538389006.py", line 1
#     for k in range(0,10)
#                         ^
# SyntaxError: invalid syntax

# %%
for j in range(0, len(rows)):

    eachRow = rows[0]
    columns = eachRow.findAll()
    columnLen = len(eachRow)

for i in range(0, columnLen):
    print(i)
    columnValue = columns[i].text
    columnList.append(columns[i])

rowList.append(columnList)
columnList = []
# Out:
#   File "C:\Users\SMART27\AppData\Local\Temp\ipykernel_5748\1074516192.py", line 3
#     eachRow = rows[0]
#     ^
# IndentationError: expected an indented block

# %%
j=0

# %%
eachRow = row[j]
columns = eachRow.findAll()
columnLen = len(columns)

for i in range(0, columnLen):
    #첫번째 행의 컬럼데이터를 수집 시 태그의 이름으로 컬럼명을 수집한다.
    if j==0:
        tagName = columns[i].name
        nameList.append(tagName)
    columnValue = columns[i].text
    columnList.append(columnValue)
    
rowList.append(columnList)
columnList = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5748\1483030278.py in <module>
# ----> 1 eachRow = row[j]
#       2 columns = eachRow.findAll()
#       3 columnLen = len(columns)
#       4
#       5 for i in range(0, columnLen):
#
# NameError: name 'row' is not defined

# %%
collectData = pd.DataFrame(rowList)

# %%
pd.DataFrame(rowList)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
import pandas as pd
