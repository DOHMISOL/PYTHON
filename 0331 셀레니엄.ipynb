# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
chromeOption = Options()

# %%
chromeOption.add_argument("window-size=1920x1080")

# %%
#driver = webdriver.Chrome(service=Service(executable_path=ChromeDriverManager().install()), options=options)

# %%
driver = webdriver.Chrome(service=Service( ChromeDriverManager().install()), 
                          options = chromeOption)

# %%
#html의 구성컴포넌트가 다 올라올때까지 최대 3초를 기다린다.
driver.implicitly_wait(3)

# %%
import time

# %%
targetUrl = "https://sparkkorea.com/"

# %%
resp = driver.get(targetUrl)

# %%
driver.current_url
# Out:
# 'https://sparkkorea.com/'

# %%
import time
import bs4

# %%
htmlCode= driver.page_source

# %%
bsObj = bs4.BeautifulSoup(htmlCode,"html.parser")

# %%
quizBtnXpath = '//*[@id="menu-item-382"]/a'

# %%
from selenium.webdriver.common.by import By

# %%
driver.find_element(By.XPATH, quizBtnXpath).click()

# %%
googleUrl = "https://www.google.co.kr/?hl=ko"

# %%
driver.get(googleUrl)

# %%
googleInputXpath = '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input'

# %%
driver.find_element(By.XPATH,googleInputXpath).send_keys("selenium")

# %%
from selenium.webdriver.common.keys import Keys

# %%
driver.find_element(By.XPATH,googleInputXpath).send_keys(Keys.ENTER)

# %%
htmlObj = driver.page_source

# %%
bs4.BeautifulSoup(htmlObj, "html.parser")
# Out:
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>selenium - Google 검색</title><script async="" nonce="" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.fpEXMBCWMKc.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo9SQGHwxhl93I-W5KEIEdf87vGuqQ/cb=gapi.loaded_0"></script><script nonce="">(function(){var b=window.addEventListener;window.addEventListener=function(a,c,d){"unload"!==a&&b(a,c,d)};}).call(this);(function(){window.google={kEI:'yEMmZOiNMofv-Qap-aDACA',kEXPI:'31',kBL:'hBCV',kOPI:89978449};google.sn='web';google.kHL='ko';})();(function(){
# ...

# %%
htmlCode = driver.page_source

# %%
import bs4

# %% [markdown]
# #이메일 자동화

# %%
to =["ehalthf0406@naver.com","doms0406@kakao.com"]

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\SMART27\\stdcode6\\Session_All_practice'

# %%
#mailData = pd.read_csv("../dataset/mailaddress.csv")
#mailData
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19780\71348252.py in <module>
# ----> 1 mailData = pd.read_csv("../dataset/mailaddress.CSV")
#       2 mailData
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#to = list( mailData.email )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19780\4192505234.py in <module>
# ----> 1 to = list( mailData.email )
#
# NameError: name 'mailData' is not defined

# %%
# SMTP 프로토콜 로드
import smtplib

# 이메일을 간단하게 보낼수 있는 라이브러리 로드
from email.message import EmailMessage

# %%
msg = EmailMessage()
msg['From'] = 'doms0406@gmail.com'
msg['To'] = ",".join(to)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19780\2498795934.py in <module>
# ----> 1 msg = EmailMessage()
#       2 msg['From'] = 'doms0406@gmail.com'
#       3 msg['To'] = ",".join(to)
#
# NameError: name 'EmailMessage' is not defined

# %%
smtp_gmail = smtplib.SMTP('smtp.gmail.com', 587)

# %%
smtp_gmail.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [112.76.111.22]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_gmail.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
userid = "doms0406@gmail.com"

# %%
import getpass

# %%
mypass = getpass.getpass()

# %%
userpw = mypass

# %%
# userid = "doms0406"
# userpw = "wvvuhpmgqgixctmu"
smtp_gmail.login(userid, userpw)

# %%
import pandas as pd
emailList =pd.read_csv("./emailaddress.csv")

# %%
emailList.이메일주소.tolist()

# %%
to = ["ehalthf0406@naver.com", "doms0406@hanmail.net"]

# %%
msg=EmailMessage()

# %%
msg['Subject']="퀴즈 정보"

# %%
msg.set_content("퀴즈정보")

# %%
msg['From']='doms0406@gmail.com'

# %%
msg['To'] = ",".join(to)

# %%
###첨부파일 메일 전송

# %%
file = '../dataset/attach.csv'
fp = open(file, 'rb')
file_data = fp.read()

msg.add_attachment(file data,
                   maintype='text',
                   subtype='plain',
                   filename=file)
#메일전송
stmp_gmail.

# %% [markdown]
# ###피클 파일 저장하기(바이너리) ###

# %%
inPass = "asdfasdfsdgasdgadsfs"

# %%
testList = ["aa","bb","cc","dd"]

# %%
import pickle
with open("./pw.pickle","wb") as fw :
    pickle.dump(inPass,fw)

# %%
with open("./pw.pickle","rb") as fr:
    data = pickle.load(fr)

# %%
data

# %%
type( data )
