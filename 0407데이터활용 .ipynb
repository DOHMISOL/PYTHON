# %%
import pandas as pd

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2            6    0.900000        Early-bird
# 4  B10634  3391.074215    2            4    2.453656      Sleeping-dog

# %% [markdown]
# 리스트로 데이터프레임 만들기

# %%
stNo = [1,2,3]
stName = ["doh","mi","sol"]

# %%
testDF = pd.DataFrame(zip(stNo, stName))
testDF
# Out:
#    0    1
# 0  1  doh
# 1  2   mi
# 2  3  sol

# %%
row1 = [1,"doh"]
row2 = [2,"mi"]
row3 = [3,"sol"]

# %%
testDF1 = pd.DataFrame([row1],[row2],[row3])
testDF1
# Out:
#     3  sol
# 2   1  doh
# mi  1  doh

# %%
testDF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2 entries, (2,) to ('mi',)
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   (3,)    2 non-null      int64
#  1   (sol,)  2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 174.0+ bytes

# %%
tableDefine = pd.DataFrame( customerData.dtypes )

# %%
tableDefine.to_csv("../dataset/tabledefine.csv")
tableDefine["비고"] = ""
tableDefine
# Out:
#                    0 비고
# CUSTID        object
# AVGPRICE     float64
# EMI            int64
# DEVICECOUNT    int64
# PRODUCTAGE   float64
# CUSTTYPE      object

# %%
customerData.loc[ 0:10 ]
# Out:
#     CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0   A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1   A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2   A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3   A16605  3713.211107    2            6    0.900000        Early-bird
# 4   B10634  3391.074215    2            4    2.453656      Sleeping-dog
# 5   B16849  3755.263391    2            4    2.786665      Sleeping-dog
# 6   B18816  3213.911446    2            6    0.900000        Early-bird
# 7   C10639  3516.500000    2            5    2.564830  Big-Screen-lover
# 8   C12717  3732.900000    2            5    2.069995  Big-Screen-lover
# 9   C15050  4020.173425    2            4    3.013440      Sleeping-dog
# 10  C18306  4005.005142    2            4    3.113618      Sleeping-dog

# %%
customerData.loc[ [0,1,2,3,4] ]
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2            6    0.900000        Early-bird
# 4  B10634  3391.074215    2            4    2.453656      Sleeping-dog

# %%
emiCondition = 3
deviceCondition = 5

# %%
csData = customerData.loc[ (customerData.EMI >= emiCondition) &
                  (customerData.DEVICECOUNT > deviceCondition) ]   #문자는 문자끼리 숫자는 숫자끼리 비교한다.

# %%
csData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 27   F17131  3179.708359    3            6    1.100000        Early-bird
# 33   G16437  3787.328898    3            6    1.000000        Early-bird
# 36   G18402  3402.199381    3            6    1.000000        Early-bird
# 40   H16326  3988.935304    3            6    0.900000        Early-bird
# 45   I12899  3018.895637    3            6    0.900000        Early-bird
# 51   J10809  3676.135627    3            6    0.800000        Early-bird
# 52   J15083  2811.265932    3            6    0.900000        Early-bird
# 53   J16445  3041.848186    3            6    0.800000        Early-bird
# 60   L13892  3263.515145    3            6    1.100000        Early-bird
# 67   N13273  3839.694732    3            6    1.100000        Early-bird
# 95   R16364  3592.353540    3            6    0.900000        Early-bird
# ...

# %%
csData.loc[ csData.DEVICECOUNT <=5 ]
# Out:
# Empty DataFrame
# Columns: [CUSTID, AVGPRICE, EMI, DEVICECOUNT, PRODUCTAGE, CUSTTYPE]
# Index: []

# %%
refinedData = \
    customerData.loc[ customerData.EMI > 2]

# %%
refinedData.loc [ customerData.EMI <= 2]   #반대의 경우도 확인해줘야함   refinedData.loc [ customerData["EMI"] > 2] 같은표현임
# Out:
# Empty DataFrame
# Columns: [CUSTID, AVGPRICE, EMI, DEVICECOUNT, PRODUCTAGE, CUSTTYPE]
# Index: []

# %% [markdown]
# 데이터프레임에서 타입변환

# %%
customerData.dtypes
# Out:
# CUSTID          object
# AVGPRICE       float64
# EMI              int64
# DEVICECOUNT      int64
# PRODUCTAGE     float64
# CUSTTYPE        object
# dtype: object

# %%
# str int float
# customerData.EMI = customerData.EMI.astype(str)
customerData["EMI_STR"] = customerData.EMI.astype(str)  # 새로운 컬럼을 만들때는 꼭 [ " " ]를 사용해야한다.

# %%
customerData
# Out:
#      CUSTID     AVGPRICE EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566  4273.900000   3            6    1.679181  Big-Screen-lover
# 1    A14219  3642.441950   2            4    2.682023      Sleeping-dog
# 2    A15312  3653.884565   2            5    3.208202      Sleeping-dog
# 3    A16605  3713.211107   2            6    0.900000        Early-bird
# 4    B10634  3391.074215   2            4    2.453656      Sleeping-dog
# ..      ...          ...  ..          ...         ...               ...
# 145  Z13253  3678.800000   2            5    2.463670  Big-Screen-lover
# 146  Z13534  3662.437527   3            6    0.900000        Early-bird
# 147  Z16428  3516.500000   2            5    2.371301  Big-Screen-lover
# 148  Z16735  3300.100000   2            5    1.704942  Big-Screen-lover
# 149  Z19835  3326.526183   2            6    1.200000        Early-bird
#
#     EMI_STR
# 0         3
# 1         2
# 2         2
# 3         2
# 4         2
# ..      ...
# ...

# %%
customerData.dtypes
# Out:
# CUSTID          object
# AVGPRICE       float64
# EMI             object
# DEVICECOUNT      int64
# PRODUCTAGE     float64
# CUSTTYPE        object
# EMI_STR         object
# dtype: object

# %%
customerData["EMI_VAR"] = customerData.EMI.astype(str)
customerData.dtypes
# Out:
# CUSTID          object
# AVGPRICE       float64
# EMI             object
# DEVICECOUNT      int64
# PRODUCTAGE     float64
# CUSTTYPE        object
# EMI_STR         object
# EMI_VAR         object
# dtype: object

# %%
customerData.dtypes
# Out:
# CUSTID          object
# AVGPRICE       float64
# EMI             object
# DEVICECOUNT      int64
# PRODUCTAGE     float64
# CUSTTYPE        object
# EMI_STR         object
# EMI_VAR         object
# dtype: object

# %%
customerData["dohmisol"] = customerData.CUSTTYPE.astype(str)
customerData.dtypes
# Out:
# CUSTID          object
# AVGPRICE       float64
# EMI             object
# DEVICECOUNT      int64
# PRODUCTAGE     float64
# CUSTTYPE        object
# EMI_STR         object
# EMI_VAR         object
# dohmisol        object
# dtype: object

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")

csColumns = list( customerData.columns )

for i in range(0, len(csColumns)):
    try :
        customerData[csColumns[i]] = customerData[ csColumns[i] ].astype(str)
    except Excption as e : 
        print(e)

# %%
customerData.dtypes
# Out:
# CUSTID         object
# AVGPRICE       object
# EMI            object
# DEVICECOUNT    object
# PRODUCTAGE     object
# CUSTTYPE       object
# dtype: object

# %%
customerData["CUSTID"] = customerData["CUSTID"].astype(str)

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")

# %%
emiCondition =[2,3]

# %%
csData = customerData.loc[customerData.EMI.isin( emiCondition )]

# %%
csData.shape
# Out:
# (11, 6)

# %%
csData = customerData.loc[~customerData.EMI.isin( emiCondition )]   # ~  isin 반대표시

# %%
customerData.loc[0:2]
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2            5    3.208202      Sleeping-dog

# %%
customerData.loc[ : ]  # 인덱스로 조회하기
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2            6    0.900000        Early-bird
# 4    B10634  3391.074215    2            4    2.453656      Sleeping-dog
# ..      ...          ...  ...          ...         ...               ...
# 145  Z13253  3678.800000    2            5    2.463670  Big-Screen-lover
# 146  Z13534  3662.437527    3            6    0.900000        Early-bird
# 147  Z16428  3516.500000    2            5    2.371301  Big-Screen-lover
# 148  Z16735  3300.100000    2            5    1.704942  Big-Screen-lover
# 149  Z19835  3326.526183    2            6    1.200000        Early-bird
#
# [150 rows x 6 columns]
